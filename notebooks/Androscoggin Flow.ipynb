# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('/data/androscoggin.txt', skiprows=28, delimiter='\t',
                 names=['Agency', 'StationID', 'Date', 'Flow', 'Flag'],
                 index_col=2, parse_dates=True)

# %%
df.head()
# Out:
#            Agency  StationID  Flow Flag
# Date
# 2000-01-01   USGS    1059000  3800    A
# 2000-01-02   USGS    1059000  3690    A
# 2000-01-03   USGS    1059000  3740    A
# 2000-01-04   USGS    1059000  5310    A
# 2000-01-05   USGS    1059000  5150    A

# %%
df['Flow'].plot()
